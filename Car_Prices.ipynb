# %% [markdown]
# ## Joseph Farag

# %% [markdown]
# # Most Important Car Features
# In this project, we aim to analyze different features in car models to detemine which are most important for the price of the car. For this analysis we'll analyse a dataset which contains various information on different features for certain car models. We read in the dataset below.

# %%
import pandas as pd
car_buyers = pd.read_csv(r"C:\Users\joefa\OneDrive\Documents\Projects\CarBuyers.csv")
car_buyers['Total'] = car_buyers['Total'].str.replace(",", "")
car_buyers['Total'] = car_buyers['Total'].astype(float)
car_buyers.head()
# Out:
#   Manufacturer   Model      Price  Transmission       Power    Engine CC  \
# 0         Ford   Focus  30.619322      5.966102   94.033898  1497.169492
# 1         Ford  Fiesta  18.532143      5.714286   68.571429  1166.142857
# 2   Volkswagen    Golf  31.242154      6.164835   89.461538  1537.406593
# 3      Renault    Clio  22.100000      5.615385   75.576923  1219.653846
# 4          BMW    320i  47.848370      6.444444  126.111111  1995.777778
#
#      Fuel    Male  Female Unknown      Total
# 0  petrol  814172  422731  56,487  1293390.0
# 1  petrol  554879  631666  54,057  1240602.0
# 2  petrol  483216  310604  47,563   841383.0
# 3  petrol  241287  312556  28,004   581847.0
# 4  petrol  408016  115843  29,125   552984.0

# %% [markdown]
# Investigating the table above, we see a number of columns that we can use to analyse whether a relationship exists between them and the price variable.

# %%
sns.heatmap(car_buyers.corr(), annot=True) #annot allows us to see numbers as well as colour correlations
plt.show()

# %% [markdown]
# We first analyse the correlations between all the numeric variables above. From this table there appears to be strong relationships between a few of the variables in the table. These are mostly positively correlated. We plot all the relationships with these variables below.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight') #specific style
sns.regplot(x=car_buyers['Power'], y=car_buyers['Price'])
plt.show()

# %%
plt.style.use('fivethirtyeight')
sns.regplot(x=car_buyers['Transmission'], y=car_buyers['Price'])
plt.show()

# %%
plt.style.use('fivethirtyeight')
sns.regplot(x=car_buyers['Engine CC'], y=car_buyers['Price'])
plt.show()

# %% [markdown]
# In these three plots, we can see what we saw in the correlation plots, with Engine CC and Power having the strongest positive correlation with the Price variable, and Transmission having a slightly weaker correlation, but still a clear trend. All three plots also accentuate clear outliers in the data that could alter the data slightly. To help counter this for more succinct results, we'll restrict the data to under $100,000.

# %%
car_buyers2 = car_buyers[car_buyers['Price'] < 100].copy()
car_buyers2.shape
# Out:
# (5647, 11)

# %%
sns.heatmap(car_buyers2.corr(), annot=True)
plt.show()

# %%
sns.regplot(x=car_buyers2['Power'], y=car_buyers2['Price'])
plt.show()

# %%
sns.regplot(x=car_buyers2['Transmission'], y=car_buyers2['Price'])
plt.show()

# %%
sns.regplot(x=car_buyers2['Engine CC'], y=car_buyers2['Price'])
plt.show()

# %% [markdown]
# The new dataset accentuates these relationships a lot clearer. We further analyse how the object variables relate to the price.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.boxplot(car_buyers['Fuel'], car_buyers['Total'])
plt.show()

# %%
sns.boxplot(x=car_buyers2['Fuel'], y=car_buyers2['Price'])
plt.show()

# %% [markdown]
# Through the boxplot analysis above, we can see the how the different fuel types affect price. While petrol covers the largest range of prices either way, diesel has the highest median and interquartile range, indicating that diesel types are more likely to have a higher price point.

# %% [markdown]
# ### Conclusions
# Through our project, we can see how different variables affect the price point of cars. The power of the car has the strongest positive correlation, as the higher the power the higher the price. This is followed by Engine CC, which also has a positive correlation, followed by the car's transmission, which is a bit weaker but still clearly positive correlated. There also appears to be a correlation between fuel types and the price of a car in the above boxplot.
